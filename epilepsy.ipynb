# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Epileptic Seizure Recognition.csv")

# %%
df
# Out:
#           Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  \
# 0      X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17
# 1      X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164
# 2         X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57
# 3       X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82
# 4       X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 11495  X22.V1.114  -22  -22  -23  -26  -36  -42  -45  -42  -45  ...    15
# 11496  X19.V1.354  -47  -11   28   77  141  211  246  240  193  ...   -65
# 11497    X8.V1.28   14    6  -13  -16   10   26   27   -9    4  ...   -65
# 11498  X10.V1.932  -40  -25   -9  -12   -2   12    7   19   22  ...   121
# 11499  X16.V1.210   29   41   57   72   74   62   54   43   31  ...   -59
#
#        X171  X172  X173  X174  X175  X176  X177  X178  y
# ...

# %%
df.shape
# Out:
# (11500, 180)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %%
df.select_dtypes(include=['object'])
# Out:
#           Unnamed
# 0      X21.V1.791
# 1      X15.V1.924
# 2         X8.V1.1
# 3       X16.V1.60
# 4       X20.V1.54
# ...           ...
# 11495  X22.V1.114
# 11496  X19.V1.354
# 11497    X8.V1.28
# 11498  X10.V1.932
# 11499  X16.V1.210
#
# [11500 rows x 1 columns]

# %%
df.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
values = df['y'].value_counts()
plt.figure(figsize=(7,7))
values.plot(kind='pie',fontsize=17, autopct='%.2f')
plt.legend(loc="best")
plt.show()

# %%
plt.rcParams["figure.figsize"] = (20, 10)
df.loc[:,::25].plot()
plt.title("Visual representation different channels when stacked aganist each other")
plt.xlabel("total number of values of x")
plt.ylabel("range of values of y")
plt.show()

# %%
df['y'].value_counts()
# Out:
# y
# 4    2300
# 1    2300
# 5    2300
# 2    2300
# 3    2300
# Name: count, dtype: int64

# %%
df['y'] = df['y'].replace([2,3,4,5],0)
df.y.value_counts()
# Out:
# y
# 0    9200
# 1    2300
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.despine(left=True)
sns.scatterplot(x='X1', y='X2', hue = 'y', data=df)
plt.show()

# %%
df1 = df.drop(['Unnamed'],axis=1)

# %%
df1
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# 0      135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15
# 1      386  382  356  331  320  315  307  272  244  232  ...   164   150
# 2      -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64
# 3     -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81
# 4       -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 11495  -22  -22  -23  -26  -36  -42  -45  -42  -45  -49  ...    15    16
# 11496  -47  -11   28   77  141  211  246  240  193  136  ...   -65   -33
# 11497   14    6  -13  -16   10   26   27   -9    4   14  ...   -65   -48
# 11498  -40  -25   -9  -12   -2   12    7   19   22   29  ...   121   135
# 11499   29   41   57   72   74   62   54   43   31   23  ...   -59   -25
#
#        X172  X173  X174  X175  X176  X177  X178  y
# ...

# %%
X = df1.iloc[:,0:178].values

# %%
y = df1['y']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=21)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report , accuracy_score , confusion_matrix

# %%
classifier_rf = RandomForestClassifier(random_state=21, n_jobs=-1, max_depth=80, n_estimators=100,max_features=10)
classifier_rf.fit(X_train,y_train)
y_pred = classifier_rf.predict(X_test)
result = confusion_matrix(y_test, y_pred)
print("Confusion matrix is \n",result)
result1 =classification_report(y_pred, y_test)
print("Classification report is\n",result1)
accuracy_rf = accuracy_score(y_pred, y_test)
print("Accuracy score is ",accuracy_rf)
# Out:
# Confusion matrix is
#  [[1811   24]
#  [  24  441]]
# Classification report is
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1835
#            1       0.95      0.95      0.95       465
#
#     accuracy                           0.98      2300
#    macro avg       0.97      0.97      0.97      2300
# weighted avg       0.98      0.98      0.98      2300
#
# Accuracy score is  0.9791304347826087

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
accuracy_result = []
for n in range(1,10):
  classifier1 = KNeighborsClassifier(n_neighbors= n,n_jobs=-1)
  classifier1.fit(X_train,y_train)
  y_pred = classifier1.predict(X_test)
  result = confusion_matrix(y_test, y_pred)
  print("Confusion matrix is \n",result)
  result1 =classification_report(y_pred, y_test)
  print("Classification report is\n",result1)
  result2 = accuracy_score(y_pred, y_test)
  print("Accuracy score is ",result2)
  accuracy_result.append(result2)
print("Accuracy result in array is",accuracy_result)
# Out:
# Confusion matrix is
#  [[1834    1]
#  [ 100  365]]
# Classification report is
#                precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97      1934
#            1       0.78      1.00      0.88       366
#
#     accuracy                           0.96      2300
#    macro avg       0.89      0.97      0.93      2300
# weighted avg       0.97      0.96      0.96      2300
#
# Accuracy score is  0.9560869565217391
# Confusion matrix is
#  [[1834    1]
#  [ 166  299]]
# Classification report is
#                precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96      2000
#            1       0.64      1.00      0.78       300
#
#     accuracy                           0.93      2300
#    macro avg       0.82      0.96      0.87      2300
# weighted avg       0.95      0.93      0.93      2300
#
# Accuracy score is  0.9273913043478261
# Confusion matrix is
#  [[1834    1]
#  [ 135  330]]
# ...

# %%
from sklearn.metrics import classification_report , accuracy_score , confusion_matrix
from sklearn.svm import SVC
svc = SVC(C = 100, kernel = 'rbf', gamma = 'scale')
svc.fit(X_train,y_train)
y_pred_svm = svc.predict(X_test)
result = confusion_matrix(y_test, y_pred_svm)
print("Confusion matrix is \n",result)
result1 = classification_report(y_pred_svm, y_test)
print("classification report is\n",result1)
accuracy_Svm = accuracy_score(y_pred_svm, y_test)
print("Accuracy score is ",accuracy_Svm)
# Out:
# Confusion matrix is
#  [[1814   21]
#  [  24  441]]
# classification report is
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1838
#            1       0.95      0.95      0.95       462
#
#     accuracy                           0.98      2300
#    macro avg       0.97      0.97      0.97      2300
# weighted avg       0.98      0.98      0.98      2300
#
# Accuracy score is  0.9804347826086957

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(178, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile the model with an appropriate learning rate and custom metrics
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with more epochs and larger batch size
model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test))

# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred_binary = [1 if pred > 0.5 else 0 for pred in y_pred]
accuracy = accuracy_score(y_test, y_pred_binary)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# C:\Users\asnan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.5593 - loss: 4.7229 - val_accuracy: 0.7287 - val_loss: 0.6108
# Epoch 2/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.7464 - loss: 0.6349 - val_accuracy: 0.8317 - val_loss: 0.4428
# Epoch 3/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.8101 - loss: 0.4754 - val_accuracy: 0.8370 - val_loss: 0.4232
# Epoch 4/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.8421 - loss: 0.4157 - val_accuracy: 0.8496 - val_loss: 0.4162
# Epoch 5/50
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2) 
pca.fit(data_scaled)

# Transform the data to the lower-dimensional space
data_pca = pca.transform(data_scaled)

# %%
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)

# Total variance explained
total_variance_explained = np.sum(explained_variance)
print("Total Variance Explained:", total_variance_explained)
# Out:
# Explained Variance Ratio: [0.05608386 0.05239441]
# Total Variance Explained: 0.10847826520884975

# %%
data_pca1 = np.array(data_pca)

# %%
data_pca1
# Out:
# array([[-0.13381214, -1.14897902],
#        [-1.71034533, -3.66417174],
#        [ 0.49519088, -0.25525149],
#        ...,
#        [-0.28998167, -0.21011799],
#        [-0.17339567, -1.13661212],
#        [-0.04561236,  0.31065236]])

# %%
X_train, X_test,y_train, y_test = train_test_split(data_pca,y,test_size=0.2,random_state=42)

# %%
classifier_rf = RandomForestClassifier(random_state=21, n_jobs=-1, max_depth=80, n_estimators=100,max_features=10)
classifier_rf.fit(X_train,y_train)
y_pred = classifier_rf.predict(X_test)
result = confusion_matrix(y_test, y_pred)
print("Confusion matrix is \n",result)
result1 =classification_report(y_pred, y_test)
print("Classification report is\n",result1)
accuracy_rf = accuracy_score(y_pred, y_test)
print("Accuracy score is ",accuracy_rf)
# Out:
# Confusion matrix is
#  [[1811   24]
#  [  24  441]]
# Classification report is
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1835
#            1       0.95      0.95      0.95       465
#
#     accuracy                           0.98      2300
#    macro avg       0.97      0.97      0.97      2300
# weighted avg       0.98      0.98      0.98      2300
#
# Accuracy score is  0.9791304347826087

# %%
hybrid_preds = [np.argmax(np.bincount([svm_pred, rf_pred])) for svm_pred, rf_pred in zip(y_pred_svm, y_pred)]
hybrid_acc = accuracy_score(y_test, hybrid_preds)
print(f"\nHybrid Model Accuracy (SVM + RF Voting): {hybrid_acc * 100:.2f}%")
print("\nHybrid Classification Report:\n")
print(classification_report(y_test, hybrid_preds))
# Out:
# Hybrid Model Accuracy (SVM + RF Voting): 98.00%
#
# Hybrid Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1835
#            1       0.98      0.92      0.95       465
#
#     accuracy                           0.98      2300
#    macro avg       0.98      0.96      0.97      2300
# weighted avg       0.98      0.98      0.98      2300

# %%
accuracy = accuracy_score(y_test, hybrid_preds)

# %%
accuracy
# Out:
# 0.98
